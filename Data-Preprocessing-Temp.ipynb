# %%
import csv
import pandas as pd
from collections import defaultdict

f = open('sharkAttack.csv', 'r')
# data = csv.reader(f, delimiter=',')

# fdir = r'C:\Users\iapetos45\Desktop\sharkAttack'
# fn = "sharkAttack.csv"

# data = pd.read_csv(fdir+fn)

# for row in data:
#     print(row)



species = ""
size = ""

for line in

f.close() 


# import pandas as pd

# fdir = r'C:\Users\KBCI\Desktop\run\\'
# fn = "shark_team.csv"

# data = pd.read_csv(fdir+fn)
# # csv읽기

# data=data.iloc[:,[10,11]]
# # 원하는 헤더(열)만 출력 
# #이 코드는 10번째[fatal]과 11번째[time]만 보기

# # data=data.dropna(how='all')
# #nan값 처내기 drop=처내기 na=nan값 
# #how=쳐내는 방식 all=전부
# # data=data.dropna().reset_index(drop=True)
# #공백칸을 쳐내는 코드


# for i in range(0,len(data)):
#     if data.iloc[i,0]=="N":
#         data.iloc[i,0]=1
#     elif data.iloc[i,0]=="Y":
#         data.iloc[i,0]=0
# #y/n > 1/0 나누는 코드

        
# print(data.head(41))

# #head(n) n번째 행 까지만 보기
# Out:
#   File "<ipython-input-1-03c7fdedaf10>", line 21
#     for line in
#                ^
# SyntaxError: invalid syntax
