# %%
# 파일을 불러오기 위한 라이브러리
import csv

# 뭔지 모르겠지만 넣으래서 넣음
import pandas as pd
from collections import defaultdict

# 파일 불러오기
f = open('sharkAttack.csv', 'r')
# 이거하고 위에꺼하고 뭐가 다른지 모르겠지만..
data = pd.read_csv("sharkAttack.csv")

# 데이터의 앞 5줄만 출력
print(data.head(5))

# 여기 CSV 데이터하고 연결해야할 것 같은데 모르겠음

# 상어 종류와 크기가 같이 적혀있는 원본 데이터
sharkSpecies = Species

# 상어 종류만 따로 분류하려는 데이터
sharkType = ""

# 상어 크기만 따로 분류하려는 데이터
sharkSize = ""

# sharkSpecies의 자료형이 문자열 혹은 정수형일 경우
if skarkSpecies is str:
    # 여기 상어 종류만 따로 떼네서 열 생성해서 쓰고 싶은데 모르겠음
    elif sharKSpecies: is int: # 이거 int로 해야되는지 잘 모르겠음
        # 여기 상어 크기만 따로 떼네서 열 생성해서 쓰고 싶은데 모르겠음
    
# 파일 닫기
f.close()
# Out:
#   File "<ipython-input-1-5020e4fcd2c0>", line 30
#     elif sharKSpecies: is int: # 이거 int로 해야되는지 잘 모르겠음
#        ^
# SyntaxError: invalid syntax
